# %% [markdown]
# <a href="https://colab.research.google.com/github/akipi-ro/b/blob/master/dip428.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# coding: utf-8
import numpy as np
import pandas as pd
import sklearn


x=pd.read_csv("train_x.csv")#説明
y=pd.read_csv("train_y.csv")#目的


x=x.dropna(how='all',axis=1)#全て欠損値の列を削除

# x.isnull().sum()[x.isnull().sum()>=15853].sort_values()
x.isnull().sum()[x.isnull().sum()<=0].sort_values()



#型の確認
na_columns = x.isnull().sum()[x.isnull().sum()>=15853].sort_values().index.tolist()#ゴミの型の確認
na_columns = x.isnull().sum()[x.isnull().sum()<=0].sort_values().index.tolist()#無欠損型の確認
x[na_columns].dtypes

# x.describe()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (114) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# 職場の様子             int64
# 勤務地　都道府県コード       int64
# 会社概要　業界コード        int64
# DTP関連のスキルを活かす     int64
# 英語力を活かす           int64
#                   ...
# 就業形態区分            int64
# 検索対象エリア           int64
# Accessのスキルを活かす    int64
# 期間・時間　勤務期間        int64
# 残業なし              int64
# Length: 103, dtype: object

# %%
x.head()
# Out:
#    職場の様子  （紹介予定）入社後の雇用形態  ...  残業なし                      期間･時間　備考
# 0      3             NaN  ...     1  ◆開始日はご相談可能です！詳しくはお問い合わせください！
# 1      3             1.0  ...     1                           NaN
# 2      3             1.0  ...     1                           NaN
# 3      2             1.0  ...     0  ◆開始日はご相談可能です！詳しくはお問い合わせください！
# 4      2             1.0  ...     0  ◆開始日はご相談可能です！詳しくはお問い合わせください！
#
# [5 rows x 127 columns]

# %% [markdown]
# #配列変換

# %%
y_array=np.array(y)
x_array=np.array(x)

# %% [markdown]
# #結果出力

# %%
# =pd.DataFrame({"Id" : houseprice_assignment["お仕事No."],"SalePrice" : y2_pred})

# %%
.to_csv("Ans.csv",index=False)

# %% [markdown]
# #テスト

# %%
X_test=pd.read_csv("test_x.csv")#testの説明変数
X_test.isnull()
# Out:
#       勤務地　最寄駅3（駅名）  ミドル（40〜）活躍中  オープニングスタッフ  ...   応募資格  WEB関連のスキルを活かす  対象者設定　年齢下限
# 0             True        False        True  ...  False           True       False
# 1             True        False        True  ...  False           True       False
# 2             True        False        True  ...  False           True       False
# 3             True        False        True  ...  False           True       False
# 4             True        False        True  ...  False           True       False
# ...            ...          ...         ...  ...    ...            ...         ...
# 3386          True        False        True  ...  False           True       False
# 3387          True        False        True  ...  False           True       False
# 3388          True        False        True  ...  False           True       False
# 3389          True        False        True  ...  False           True       False
# 3390          True        False        True  ...  False           True       False
#
# [3391 rows x 212 columns]
